# %%
import sys
import os

sys.path.append(os.path.abspath('../../scripts'))

import commons_tsv

input_file = '../../../mtg-jamendo-dataset/data/autotagging_genre.tsv'
tracks, tags, extra = commons_tsv.read_file(input_file)
# Out:
# ...
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 759
# 760
# 761
# 762
# 763
# 764
# 765
# 766
# 767
# 768
# 769
# 770
# 771
# 772
# 773
# 774
# 775
# 776
# 808
# 809
# 810
# 843
# 844
# 851
# 852
# 853
# 854
# 855
# 856
# 946
# 947
# 948
# 949
# 950
# 951
# 952
# 953
# 954
# 955
# 956
# 957
# 958
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1161
# 1260
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# 1269
# 1271
# 1286
# 1287
# 1288
# 1289
# 1290
# 1291
# 1292
# 1293
# 1294
# 1332
# 1333
# 1334
# 1336
# 1341
# 1556
# 1603
# 1604
# 1606
# 1729
# 1730
# 1731
# 1732
# 1733
# 1736
# 1941
# 1945
# 1947
# 2011
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2164
# 2165
# 2166
# 2167
# 2168
# 2169
# 2170
# 2171
# ...

# %%
tracks
# Out:
# {214: {'artist_id': 14,
#   'album_id': 31,
#   'path': '14/214.mp3',
#   'duration': 124.6,
#   'tags': ['genre---punkrock'],
#   'genre': {'punkrock'},
#   'instrument': set(),
#   'mood/theme': set()},
#  215: {'artist_id': 14,
#   'album_id': 31,
#   'path': '15/215.mp3',
#   'duration': 151.4,
#   'tags': ['genre---metal'],
#   'genre': {'metal'},
#   'instrument': set(),
#   'mood/theme': set()},
#  216: {'artist_id': 14,
#   'album_id': 31,
#   'path': '16/216.mp3',
#   'duration': 234.9,
#   'tags': ['genre---metal'],
#   'genre': {'metal'},
#   'instrument': set(),
#   'mood/theme': set()},
#  217: {'artist_id': 14,
#   'album_id': 31,
#   'path': '17/217.mp3',
#   'duration': 127.9,
#   'tags': ['genre---punkrock'],
#   'genre': {'punkrock'},
#   'instrument': set(),
#   'mood/theme': set()},
#  218: {'artist_id': 14,
#   'album_id': 31,
#   'path': '18/218.mp3',
#   'duration': 180.7,
#   'tags': ['genre---punkrock'],
#   'genre': {'punkrock'},
#   'instrument': set(),
# ...
